# %% [markdown]
# Arithmetic Operations

# %%
import pandas as pd
var=pd.DataFrame({"A":[1,2,3],"B":[4,5,6]})
print(var)

# %%
var["C"]=var["A"]%var["B"]
print(var)

# %%
var["Python"] = var["A"].le(20)      
var["Python_1"] = var["B"].le(60)
print(var[["Python", "Python_1"]])
