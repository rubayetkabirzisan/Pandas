# %% [markdown]
# Python Pandas CSV Files

# %% [markdown]
# write CSV Files

# %%
import pandas as pd
var = pd.DataFrame({"A":[1,2,3,4,5],
                    "B":[6,7,8,9,10]})
d=pd.DataFrame(var)
print(d)
d.to_csv("test.csv",index=False,header=["col1","col2"])
