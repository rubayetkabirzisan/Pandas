# %% [markdown]
# python csv file reading and writing

# %% [markdown]
# pandas function

# %%
import pandas as pd
csv_1 = pd.read_csv("e:/Pandas/Video 8/test.csv")
# csv_1.index
# csv_1.columns
# csv_1.count()
# csv_1.dtypes
# csv_1.head(2)
# csv_1.tail(3)
# csv_1.describe()
# csv_1.to_csv("e:/Pandas/Video 8/test_new.csv")
# csv_1[:5]
# print(type(csv_1))
# csv_1.index.array
# csv_1.to_numpy()
# import numpy as np
# arr = np.array(csv_1)
# arr
# csv_1.sort_index(axis=0,ascending=False)
# csv_1["col1"][0]=100
# csv_1
# csv_1.loc[0,"col1"]=100
# csv_1
# csv_1.loc[[0,2],["col1","col2"]]=200  
# csv_1
# d=csv_1.iloc[2,1]
# d
# d1=csv_1.drop(0,axis=0)
# d1
# Out:
#    col1  col2
# 1     2     7
# 2     3     8
# 3     4     9
# 4     5    10
