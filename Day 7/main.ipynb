# %% [markdown]
# Reading Data from CSV Files

# %%
import pandas as pd

# read_csv = pd.read_csv("E:/Pandas/Video 7/test.csv")
# read_csv

# read_csv1 = pd.read_csv("E:/Pandas/Video 7/test.csv",nrows=3)
# print(read_csv1)

# read_csv2 = pd.read_csv("E:/Pandas/Video 7/test.csv",usecols=["col1"])
# print(read_csv2)

# read_csv3 = pd.read_csv("E:/Pandas/Video 7/test.csv",skiprows=2)
# print(read_csv3)

# read_csv4 = pd.read_csv("E:/Pandas/Video 7/test.csv",index_col="col1")
# print(read_csv4)

# read_csv5 = pd.read_csv("E:/Pandas/Video 7/test.csv",header=0)
# print(read_csv5)

# read_csv6 = pd.read_csv("E:/Pandas/Video 7/test.csv",names=["A","B"])
# print(read_csv6)

read_csv7 = pd.read_csv("E:/Pandas/Video 7/test.csv", header=None, dtype=str)
read_csv7 = read_csv7.add_prefix('column')
print(read_csv7)
