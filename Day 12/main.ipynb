# %% [markdown]
# Pandas GroupBy

# %%
import pandas as pd

var = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three']
})

# print(var)
# var_1=var.groupby("A")
# print(var_1)
# for x,y in var_1:
#     print(x)
#     print(y)


grouped = var.groupby("A")

# print(grouped.get_group("foo"))

# grouped.max()
# grouped.min()

li=list(grouped)
li
